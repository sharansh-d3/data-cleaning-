# %%
"sales"
# Out:
# 'sales'

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Vivek Chauhan\Desktop\New folder\sales_data_sample.csv", encoding='ISO-8859-1')

print(data.head())
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
data.shape
# Out:
# (2823, 25)

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
data['FullName'] = data['CONTACTFIRSTNAME'] + ' ' + data['CONTACTLASTNAME']
data = data.drop(columns=['CONTACTFIRSTNAME', 'CONTACTLASTNAME','YEAR_ID','MONTH_ID'])

# %%
data.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  PRODUCTLINE  MSRP  ...             PHONE  \
# 0   2/24/2003 0:00  Shipped       1  Motorcycles    95  ...        2125557818
# 1    5/7/2003 0:00  Shipped       2  Motorcycles    95  ...        26.47.1555
# 2    7/1/2003 0:00  Shipped       3  Motorcycles    95  ...  +33 1 46 62 7555
# 3   8/25/2003 0:00  Shipped       3  Motorcycles    95  ...        6265557265
# 4  10/10/2003 0:00  Shipped       4  Motorcycles    95  ...        6505551386
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# ...

# %%
data["ORDERNUMBER"].drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (2823, 22)

# %%
pd.isnull(data).sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# PHONE                 0
# ADDRESSLINE1          0
# ADDRESSLINE2       2521
# CITY                  0
# STATE              1486
# POSTALCODE           76
# COUNTRY               0
# TERRITORY          1074
# DEALSIZE              0
# FullName              0
# dtype: int64

# %%
data['ADDRESSLINE2'] = data['ADDRESSLINE2'].fillna(0)
data['STATE'] = data['STATE'].fillna(0)
data['TERRITORY'] = data['TERRITORY'].fillna(0)
data['POSTALCODE'] = data['POSTALCODE'].fillna(0)

# %%
pd.isnull(data).sum()
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# ORDERDATE          0
# STATUS             0
# QTR_ID             0
# PRODUCTLINE        0
# MSRP               0
# PRODUCTCODE        0
# CUSTOMERNAME       0
# PHONE              0
# ADDRESSLINE1       0
# ADDRESSLINE2       0
# CITY               0
# STATE              0
# POSTALCODE         0
# COUNTRY            0
# TERRITORY          0
# DEALSIZE           0
# FullName           0
# dtype: int64

# %%
data.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000
# mean    3553.889072     2.717676   100.715551
# std     1841.865106     1.203878    40.187912
# min      482.130000     1.000000    33.000000
# 25%     2203.430000     2.000000    68.000000
# 50%     3184.800000     3.000000    99.000000
# ...

# %%
data['ORDERDATE'] = pd.to_datetime(data['ORDERDATE'])
data["ORDERDATE"].head(10)
# Out:
# 0   2003-02-24
# 1   2003-05-07
# 2   2003-07-01
# 3   2003-08-25
# 4   2003-10-10
# 5   2003-10-28
# 6   2003-11-11
# 7   2003-11-18
# 8   2003-12-01
# 9   2004-01-15
# Name: ORDERDATE, dtype: datetime64[ns]

# %%
data.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  PRODUCTLINE  MSRP  ...             PHONE  \
# 0 2003-02-24  Shipped       1  Motorcycles    95  ...        2125557818
# 1 2003-05-07  Shipped       2  Motorcycles    95  ...        26.47.1555
# 2 2003-07-01  Shipped       3  Motorcycles    95  ...  +33 1 46 62 7555
# 3 2003-08-25  Shipped       3  Motorcycles    95  ...        6265557265
# 4 2003-10-10  Shipped       4  Motorcycles    95  ...        6505551386
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# ...

# %%
data.columns = data.columns.str.lower()
data.head()
# Out:
#    ordernumber  quantityordered  priceeach  orderlinenumber    sales  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    orderdate   status  qtr_id  productline  msrp  ...             phone  \
# 0 2003-02-24  Shipped       1  Motorcycles    95  ...        2125557818
# 1 2003-05-07  Shipped       2  Motorcycles    95  ...        26.47.1555
# 2 2003-07-01  Shipped       3  Motorcycles    95  ...  +33 1 46 62 7555
# 3 2003-08-25  Shipped       3  Motorcycles    95  ...        6265557265
# 4 2003-10-10  Shipped       4  Motorcycles    95  ...        6505551386
#
#                     addressline1 addressline2           city state postalcode  \
# ...

# %%
data.dtypes
# Out:
# ordernumber                 int64
# quantityordered             int64
# priceeach                 float64
# orderlinenumber             int64
# sales                     float64
# orderdate          datetime64[ns]
# status                     object
# qtr_id                      int64
# productline                object
# msrp                        int64
# productcode                object
# customername               object
# phone                      object
# addressline1               object
# addressline2               object
# city                       object
# state                      object
# postalcode                 object
# country                    object
# territory                  object
# dealsize                   object
# fullname                   object
# dtype: object

# %%
data['phone'] = data['phone'].astype(str).str.replace(r'\D', '', regex=True).astype('int64')
data['postalcode'] = data['postalcode'].astype(str).str.replace(r'\D', '', regex=True).astype('int64')

# %%
data.head(10)
# Out:
#    ordernumber  quantityordered  priceeach  orderlinenumber    sales  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#    orderdate   status  qtr_id  productline  msrp  ...        phone  \
# 0 2003-02-24  Shipped       1  Motorcycles    95  ...   2125557818
# 1 2003-05-07  Shipped       2  Motorcycles    95  ...     26471555
# ...
